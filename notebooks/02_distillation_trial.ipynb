# %% [markdown]
# # 02 Distillation Trial\nAdversarially hardened distillation experiment with optional Hugging Face checkpoint push.

# %%
import os\nHF_TOKEN = os.getenv('HF_TOKEN', '')\nprint('HF token loaded:', bool(HF_TOKEN))

# %%
# TODO: add MyTorch model + distillation loop hooks

# %%
# from huggingface_hub import HfApi\n# api = HfApi(token=HF_TOKEN)\n# api.upload_file(...)
