# %% [markdown]
# # 02 Distillation Trial\nReal distillation workflow: train -> save under models/ -> upload to Hugging Face Hub.

# %%
import os\nprint('HF token loaded:', bool(os.getenv('HF_TOKEN')))

# %%
# TODO: Replace with your actual MyTorch training call that writes to ../models\n!python ../src/data/prepare_dataset.py --input-root ../data/raw --output-root ../data/processed/intel_scenes --val-ratio 0.1
# !python ../src/train.py --data-root ../data/processed/intel_scenes --epochs 10 --batch-size 32 --img-size 160 --lr 5e-4 --adv-eps 0.005 --save-dir ../models/intel_run --pretrained

# %%
HF_REPO = 'ShiroOnigami23/shironet-edge'

# %%
# !python ../scripts/hf_upload.py --repo-id {HF_REPO} --local-dir ../models/intel_run --path-in-repo checkpoints/intel-run --private
