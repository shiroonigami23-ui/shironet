# %% [markdown]
# # 01 Baseline Test\nReal baseline pipeline: Kaggle download -> inspect data -> start training.

# %%
import os\nfrom pathlib import Path\nprint('KAGGLE auth via env:', bool(os.getenv('KAGGLE_USERNAME') and os.getenv('KAGGLE_KEY')))\nprint('kaggle.json exists:', (Path.home() / '.kaggle' / 'kaggle.json').exists())

# %%
# Replace with your actual dataset slug\nDATASET = 'paultimothymooney/chest-xray-pneumonia'

# %%
# !python ../scripts/kaggle_fetch.py --dataset {DATASET} --out ../data/raw

# %%
# !dir ..\data\raw
