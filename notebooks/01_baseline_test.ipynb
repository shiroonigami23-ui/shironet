# %% [markdown]
# # 01 Baseline Test\nBaseline sanity run with Kaggle dataset ingestion and MyTorch bootstrap.

# %%
# Optional: Kaggle auth\nimport os\nos.environ['KAGGLE_USERNAME'] = os.getenv('KAGGLE_USERNAME', '')\nos.environ['KAGGLE_KEY'] = os.getenv('KAGGLE_KEY', '')

# %%
# Example dataset pull (edit owner/dataset)\n# !kaggle datasets download -d owner/dataset -p ../data/raw --unzip

# %%
print('Baseline notebook ready')
